# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
from pathlib import Path
sys.path.append(str(Path(os.getcwd()).parent.absolute()))

# %%
import mujoco
import mujoco.viewer
from pathlib import Path

import numpy as np
from robot import kinematics
from robot.sim import LEFT_KINEMATIC_CHAIN, RIGHT_KINEMATIC_CHAIN, BimanualSim, randomize_block_position

from policy.privileged_policy import PrivilegedPolicy

with BimanualSim(merge_xml_files=[Path('block.xml')], on_mujoco_init=randomize_block_position) as sim:
  policy = PrivilegedPolicy(sim.model, sim.data)
  
  prev_time = sim.data.time
  obs = sim.get_obs()
  recent_min_gripper_deviation = 0.0
  recent_min_gripper_deviation_r = 0.0
  gripper_deviation_stable_for = 0
  gripper_deviation_stable_for_r = 0
  with mujoco.viewer.launch_passive(sim.model, sim.data) as viewer:
    while viewer.is_running():
      if sim.data.time < prev_time:
        sim.reset()
      prev_time = sim.data.time

      # ubiquitous obs+action sim step loop
      action = policy(obs)
      obs = sim.step(action)

      block_pos = sim.data.xpos[mujoco.mj_name2id(sim.model, mujoco.mjtObj.mjOBJ_BODY, 'block')]
      gripper_pos, _ = kinematics.augmented_forward(RIGHT_KINEMATIC_CHAIN, obs.qpos.right_arm[:-2], np.array([0.1, 0.0, 0.0]))
      gripper_pos_l, _ = kinematics.augmented_forward(LEFT_KINEMATIC_CHAIN, obs.qpos.left_arm[:-2], np.array([0.1, 0.0, 0.0]))
      block_close_to_gripper = np.linalg.norm(block_pos - gripper_pos).item() < 0.05
      block_far_from_left = np.linalg.norm(block_pos - gripper_pos_l).item() > 0.2

      current_gripper_obs_r = obs.qpos.to_approximate_action().right_gripper
      gripper_deviation_r = obs.qpos.to_approximate_action().right_gripper - action.right_gripper

      current_gripper_obs = obs.qpos.to_approximate_action().left_gripper
      gripper_deviation = obs.qpos.to_approximate_action().left_gripper - action.left_gripper
      grip = False
      if not recent_min_gripper_deviation - 0.01 < gripper_deviation < recent_min_gripper_deviation + 0.01:
        # print('reset', gripper_deviation)
        recent_min_gripper_deviation = gripper_deviation
        gripper_deviation_stable_for = 0
      else:
        if gripper_deviation_stable_for > 10 and gripper_deviation > 0.2:
          grip = True
        gripper_deviation_stable_for += 1
      grip_r = False
      success = False
      if not recent_min_gripper_deviation_r - 0.01 < gripper_deviation_r < recent_min_gripper_deviation_r + 0.01:
        # print('reset', gripper_deviation)
        recent_min_gripper_deviation_r = gripper_deviation_r
        gripper_deviation_stable_for_r = 0
      else:
        if gripper_deviation_stable_for_r > 10 and gripper_deviation_r > 0.2:
          grip_r = True
          if block_close_to_gripper and block_far_from_left:
            success = True
        gripper_deviation_stable_for_r += 1
      print(f'l: {grip}, r: {grip_r}, success: {success} {sim.data.time:.2f}')
      viewer.sync()
      if success:
        break
# Out:
# l: False, r: False, success: False 0.01
# l: False, r: False, success: False 0.02
# l: False, r: False, success: False 0.03
# l: False, r: False, success: False 0.04
# l: False, r: False, success: False 0.05
# l: False, r: False, success: False 0.06
# l: False, r: False, success: False 0.07
# l: False, r: False, success: False 0.08
# l: False, r: False, success: False 0.09
# l: False, r: False, success: False 0.10
# l: False, r: False, success: False 0.11
# l: False, r: False, success: False 0.12
# l: False, r: False, success: False 0.13
# l: False, r: False, success: False 0.14
# l: False, r: False, success: False 0.15
# l: False, r: False, success: False 0.16
# l: False, r: False, success: False 0.17
# l: False, r: False, success: False 0.18
# l: False, r: False, success: False 0.19
# l: False, r: False, success: False 0.20
# l: False, r: False, success: False 0.21
# l: False, r: False, success: False 0.22
# l: False, r: False, success: False 0.23
# l: False, r: False, success: False 0.24
# l: False, r: False, success: False 0.25
# l: False, r: False, success: False 0.26
# l: False, r: False, success: False 0.27
# l: False, r: False, success: False 0.28
# l: False, r: False, success: False 0.29
# l: False, r: False, success: False 0.30
# l: False, r: False, success: False 0.31
# l: False, r: False, success: False 0.32
# l: False, r: False, success: False 0.33
# l: False, r: False, success: False 0.34
# l: False, r: False, success: False 0.35
# l: False, r: False, success: False 0.36
# l: False, r: False, success: False 0.37
# l: False, r: False, success: False 0.38
# l: False, r: False, success: False 0.39
# l: False, r: False, success: False 0.40
# l: False, r: False, success: False 0.41
# l: False, r: False, success: False 0.42
# l: False, r: False, success: False 0.43
# l: False, r: False, success: False 0.44
# l: False, r: False, success: False 0.45
# l: False, r: False, success: False 0.46
# l: False, r: False, success: False 0.47
# l: False, r: False, success: False 0.48
# l: False, r: False, success: False 0.49
# l: False, r: False, success: False 0.50
# l: False, r: False, success: False 0.51
# l: False, r: False, success: False 0.52
# l: False, r: False, success: False 0.53
# l: False, r: False, success: False 0.54
# l: False, r: False, success: False 0.55
# l: False, r: False, success: False 0.56
# l: False, r: False, success: False 0.57
# l: False, r: False, success: False 0.58
# l: False, r: False, success: False 0.59
# l: False, r: False, success: False 0.60
# l: False, r: False, success: False 0.61
# l: False, r: False, success: False 0.62
# l: False, r: False, success: False 0.63
# l: False, r: False, success: False 0.64
# l: False, r: False, success: False 0.65
# l: False, r: False, success: False 0.66
# l: False, r: False, success: False 0.67
# l: False, r: False, success: False 0.68
# l: False, r: False, success: False 0.69
# l: False, r: False, success: False 0.70
# l: False, r: False, success: False 0.71
# l: False, r: False, success: False 0.72
# l: False, r: False, success: False 0.73
# l: False, r: False, success: False 0.74
# l: False, r: False, success: False 0.75
# l: False, r: False, success: False 0.76
# l: False, r: False, success: False 0.77
# l: False, r: False, success: False 0.78
# l: False, r: False, success: False 0.79
# l: False, r: False, success: False 0.80
# l: False, r: False, success: False 0.81
# l: False, r: False, success: False 0.82
# l: False, r: False, success: False 0.83
# l: False, r: False, success: False 0.84
# l: False, r: False, success: False 0.85
# l: False, r: False, success: False 0.86
# l: False, r: False, success: False 0.87
# l: False, r: False, success: False 0.88
# l: False, r: False, success: False 0.89
# l: False, r: False, success: False 0.90
# l: False, r: False, success: False 0.91
# l: False, r: False, success: False 0.92
# l: False, r: False, success: False 0.93
# l: False, r: False, success: False 0.94
# l: False, r: False, success: False 0.95
# l: False, r: False, success: False 0.96
# l: False, r: False, success: False 0.97
# l: False, r: False, success: False 0.98
# l: False, r: False, success: False 0.99
# l: False, r: False, success: False 1.00
# l: False, r: False, success: False 1.01
# l: False, r: False, success: False 1.02
# l: False, r: False, success: False 1.03
# l: False, r: False, success: False 1.04
# l: False, r: False, success: False 1.05
# l: False, r: False, success: False 1.06
# l: False, r: False, success: False 1.07
# l: False, r: False, success: False 1.08
# l: False, r: False, success: False 1.09
# l: False, r: False, success: False 1.10
# l: False, r: False, success: False 1.11
# l: False, r: False, success: False 1.12
# l: False, r: False, success: False 1.13
# l: False, r: False, success: False 1.14
# l: False, r: False, success: False 1.15
# l: False, r: False, success: False 1.16
# l: False, r: False, success: False 1.17
# l: False, r: False, success: False 1.18
# l: False, r: False, success: False 1.19
# l: False, r: False, success: False 1.20
# l: False, r: False, success: False 1.21
# l: False, r: False, success: False 1.22
# l: False, r: False, success: False 1.23
# l: False, r: False, success: False 1.24
# l: False, r: False, success: False 1.25
# l: False, r: False, success: False 1.26
# l: False, r: False, success: False 1.27
# l: False, r: False, success: False 1.28
# l: False, r: False, success: False 1.29
# l: False, r: False, success: False 1.30
# l: False, r: False, success: False 1.31
# l: False, r: False, success: False 1.32
# l: False, r: False, success: False 1.33
# l: False, r: False, success: False 1.34
# l: False, r: False, success: False 1.35
# l: False, r: False, success: False 1.36
# l: False, r: False, success: False 1.37
# l: False, r: False, success: False 1.38
# l: False, r: False, success: False 1.39
# l: False, r: False, success: False 1.40
# l: False, r: False, success: False 1.41
# l: False, r: False, success: False 1.42
# l: False, r: False, success: False 1.43
# l: False, r: False, success: False 1.44
# l: False, r: False, success: False 1.45
# l: False, r: False, success: False 1.46
# l: False, r: False, success: False 1.47
# l: False, r: False, success: False 1.48
# l: False, r: False, success: False 1.49
# l: False, r: False, success: False 1.50
# l: False, r: False, success: False 1.51
# l: False, r: False, success: False 1.52
# l: False, r: False, success: False 1.53
# l: False, r: False, success: False 1.54
# l: False, r: False, success: False 1.55
# l: False, r: False, success: False 1.56
# l: False, r: False, success: False 1.57
# l: False, r: False, success: False 1.58
# l: False, r: False, success: False 1.59
# l: False, r: False, success: False 1.60
# l: False, r: False, success: False 1.61
# l: False, r: False, success: False 1.62
# l: True, r: False, success: False 1.63
# l: True, r: False, success: False 1.64
# l: True, r: False, success: False 1.65
# l: True, r: False, success: False 1.66
# l: True, r: False, success: False 1.67
# l: True, r: False, success: False 1.68
# l: True, r: False, success: False 1.69
# l: True, r: False, success: False 1.70
# l: True, r: False, success: False 1.71
# l: True, r: False, success: False 1.72
# l: True, r: False, success: False 1.73
# l: True, r: False, success: False 1.74
# l: True, r: False, success: False 1.75
# l: True, r: False, success: False 1.76
# l: True, r: False, success: False 1.77
# l: True, r: False, success: False 1.78
# l: True, r: False, success: False 1.79
# l: True, r: False, success: False 1.80
# l: True, r: False, success: False 1.81
# l: True, r: False, success: False 1.82
# l: True, r: False, success: False 1.83
# l: True, r: False, success: False 1.84
# l: True, r: False, success: False 1.85
# l: True, r: False, success: False 1.86
# l: True, r: False, success: False 1.87
# l: True, r: False, success: False 1.88
# l: True, r: False, success: False 1.89
# l: True, r: False, success: False 1.90
# l: True, r: False, success: False 1.91
# l: True, r: False, success: False 1.92
# l: True, r: False, success: False 1.93
# l: True, r: False, success: False 1.94
# l: True, r: False, success: False 1.95
# l: True, r: False, success: False 1.96
# l: True, r: False, success: False 1.97
# l: True, r: False, success: False 1.98
# l: True, r: False, success: False 1.99
# l: True, r: False, success: False 2.00
# l: True, r: False, success: False 2.01
# l: True, r: False, success: False 2.02
# l: True, r: False, success: False 2.03
# l: True, r: False, success: False 2.04
# l: True, r: False, success: False 2.05
# l: True, r: False, success: False 2.06
# l: True, r: False, success: False 2.07
# l: True, r: False, success: False 2.08
# l: True, r: False, success: False 2.09
# l: True, r: False, success: False 2.10
# l: True, r: False, success: False 2.11
# l: True, r: False, success: False 2.12
# l: True, r: False, success: False 2.13
# l: True, r: False, success: False 2.14
# l: True, r: False, success: False 2.15
# l: True, r: False, success: False 2.16
# l: True, r: False, success: False 2.17
# l: True, r: False, success: False 2.18
# l: True, r: False, success: False 2.19
# l: True, r: False, success: False 2.20
# l: True, r: False, success: False 2.21
# l: True, r: False, success: False 2.22
# l: True, r: False, success: False 2.23
# l: True, r: False, success: False 2.24
# l: True, r: False, success: False 2.25
# l: True, r: False, success: False 2.26
# l: True, r: False, success: False 2.27
# l: True, r: False, success: False 2.28
# l: True, r: False, success: False 2.29
# l: True, r: False, success: False 2.30
# l: True, r: False, success: False 2.31
# l: True, r: False, success: False 2.32
# l: True, r: False, success: False 2.33
# l: True, r: False, success: False 2.34
# l: True, r: False, success: False 2.35
# l: True, r: False, success: False 2.36
# l: True, r: False, success: False 2.37
# l: True, r: False, success: False 2.38
# l: True, r: False, success: False 2.39
# l: True, r: False, success: False 2.40
# l: True, r: False, success: False 2.41
# l: True, r: False, success: False 2.42
# l: True, r: False, success: False 2.43
# l: True, r: False, success: False 2.44
# l: True, r: False, success: False 2.45
# l: True, r: False, success: False 2.46
# l: True, r: False, success: False 2.47
# l: True, r: False, success: False 2.48
# l: True, r: False, success: False 2.49
# l: True, r: False, success: False 2.50
# l: True, r: False, success: False 2.51
# l: True, r: False, success: False 2.52
# l: True, r: False, success: False 2.53
# l: True, r: False, success: False 2.54
# l: True, r: False, success: False 2.55
# l: True, r: False, success: False 2.56
# l: True, r: False, success: False 2.57
# l: True, r: False, success: False 2.58
# l: True, r: False, success: False 2.59
# l: True, r: False, success: False 2.60
# l: True, r: False, success: False 2.61
# l: True, r: False, success: False 2.62
# l: True, r: False, success: False 2.63
# l: True, r: False, success: False 2.64
# l: True, r: False, success: False 2.65
# l: True, r: False, success: False 2.66
# l: True, r: False, success: False 2.67
# l: True, r: False, success: False 2.68
# l: True, r: False, success: False 2.69
# l: True, r: False, success: False 2.70
# l: True, r: False, success: False 2.71
# l: True, r: False, success: False 2.72
# l: True, r: False, success: False 2.73
# l: True, r: False, success: False 2.74
# l: True, r: False, success: False 2.75
# l: True, r: False, success: False 2.76
# l: True, r: False, success: False 2.77
# l: True, r: False, success: False 2.78
# l: True, r: False, success: False 2.79
# l: True, r: False, success: False 2.80
# l: True, r: False, success: False 2.81
# l: True, r: False, success: False 2.82
# l: True, r: False, success: False 2.83
# l: True, r: False, success: False 2.84
# l: True, r: False, success: False 2.85
# l: True, r: False, success: False 2.86
# l: True, r: False, success: False 2.87
# l: True, r: False, success: False 2.88
# l: True, r: False, success: False 2.89
# l: True, r: False, success: False 2.90
# l: True, r: False, success: False 2.91
# l: True, r: False, success: False 2.92
# l: True, r: False, success: False 2.93
# l: True, r: False, success: False 2.94
# l: True, r: False, success: False 2.95
# l: True, r: False, success: False 2.96
# l: True, r: False, success: False 2.97
# l: True, r: False, success: False 2.98
# l: True, r: False, success: False 2.99
# l: True, r: False, success: False 3.00
# l: True, r: False, success: False 3.01
# l: True, r: False, success: False 3.02
# l: True, r: False, success: False 3.03
# l: True, r: False, success: False 3.04
# l: True, r: False, success: False 3.05
# l: True, r: False, success: False 3.06
# l: True, r: False, success: False 3.07
# l: True, r: False, success: False 3.08
# l: True, r: False, success: False 3.09
# l: True, r: False, success: False 3.10
# l: True, r: False, success: False 3.11
# l: True, r: False, success: False 3.12
# l: True, r: False, success: False 3.13
# l: True, r: False, success: False 3.14
# l: True, r: False, success: False 3.15
# l: True, r: False, success: False 3.16
# l: True, r: False, success: False 3.17
# l: True, r: False, success: False 3.18
# l: True, r: False, success: False 3.19
# l: True, r: False, success: False 3.20
# l: True, r: False, success: False 3.21
# l: True, r: False, success: False 3.22
# l: True, r: False, success: False 3.23
# l: True, r: False, success: False 3.24
# l: True, r: False, success: False 3.25
# l: True, r: False, success: False 3.26
# l: True, r: False, success: False 3.27
# l: True, r: False, success: False 3.28
# l: True, r: False, success: False 3.29
# l: True, r: False, success: False 3.30
# l: True, r: False, success: False 3.31
# l: True, r: False, success: False 3.32
# l: True, r: False, success: False 3.33
# l: True, r: False, success: False 3.34
# l: True, r: False, success: False 3.35
# l: True, r: False, success: False 3.36
# l: True, r: False, success: False 3.37
# l: True, r: False, success: False 3.38
# l: True, r: False, success: False 3.39
# l: True, r: False, success: False 3.40
# l: True, r: False, success: False 3.41
# l: True, r: False, success: False 3.42
# l: True, r: False, success: False 3.43
# l: True, r: False, success: False 3.44
# l: True, r: False, success: False 3.45
# l: True, r: False, success: False 3.46
# l: True, r: False, success: False 3.47
# l: True, r: False, success: False 3.48
# l: True, r: False, success: False 3.49
# l: True, r: False, success: False 3.50
# l: True, r: False, success: False 3.51
# l: True, r: False, success: False 3.52
# l: True, r: False, success: False 3.53
# l: True, r: False, success: False 3.54
# l: True, r: False, success: False 3.55
# l: True, r: False, success: False 3.56
# l: True, r: False, success: False 3.57
# l: True, r: False, success: False 3.58
# l: True, r: False, success: False 3.59
# l: True, r: False, success: False 3.60
# l: True, r: False, success: False 3.61
# l: True, r: False, success: False 3.62
# l: True, r: False, success: False 3.63
# l: True, r: False, success: False 3.64
# l: True, r: False, success: False 3.65
# l: True, r: False, success: False 3.66
# l: True, r: False, success: False 3.67
# l: True, r: False, success: False 3.68
# l: True, r: False, success: False 3.69
# l: True, r: False, success: False 3.70
# l: True, r: False, success: False 3.71
# l: True, r: False, success: False 3.72
# l: True, r: False, success: False 3.73
# l: True, r: False, success: False 3.74
# l: True, r: False, success: False 3.75
# l: True, r: False, success: False 3.76
# l: True, r: False, success: False 3.77
# l: True, r: False, success: False 3.78
# l: True, r: False, success: False 3.79
# l: True, r: False, success: False 3.80
# l: True, r: False, success: False 3.81
# l: True, r: False, success: False 3.82
# l: True, r: False, success: False 3.83
# l: True, r: False, success: False 3.84
# l: True, r: False, success: False 3.85
# l: True, r: False, success: False 3.86
# l: True, r: False, success: False 3.87
# l: True, r: False, success: False 3.88
# l: True, r: False, success: False 3.89
# l: True, r: False, success: False 3.90
# l: True, r: False, success: False 3.91
# l: False, r: False, success: False 3.92
# l: False, r: False, success: False 3.93
# l: False, r: False, success: False 3.94
# l: False, r: False, success: False 3.95
# l: False, r: False, success: False 3.96
# l: False, r: False, success: False 3.97
# l: False, r: False, success: False 3.98
# l: False, r: False, success: False 3.99
# l: False, r: False, success: False 4.00
# l: False, r: False, success: False 4.01
# l: False, r: True, success: False 4.02
# l: False, r: True, success: False 4.03
# l: False, r: True, success: False 4.04
# l: False, r: True, success: False 4.05
# l: False, r: False, success: False 4.06
# l: False, r: False, success: False 4.07
# l: False, r: False, success: False 4.08
# l: False, r: False, success: False 4.09
# l: False, r: False, success: False 4.10
# l: False, r: False, success: False 4.11
# l: False, r: False, success: False 4.12
# l: False, r: False, success: False 4.13
# l: False, r: False, success: False 4.14
# l: False, r: False, success: False 4.15
# l: False, r: False, success: False 4.16
# l: False, r: False, success: False 4.17
# l: False, r: False, success: False 4.18
# l: False, r: False, success: False 4.19
# l: False, r: False, success: False 4.20
# l: False, r: False, success: False 4.21
# l: False, r: False, success: False 4.22
# l: False, r: False, success: False 4.23
# l: False, r: False, success: False 4.24
# l: False, r: False, success: False 4.25
# l: False, r: False, success: False 4.26
# l: False, r: False, success: False 4.27
# l: False, r: False, success: False 4.28
# l: False, r: False, success: False 4.29
# l: False, r: False, success: False 4.30
# l: False, r: False, success: False 4.31
# l: False, r: False, success: False 4.32
# l: False, r: False, success: False 4.33
# l: False, r: False, success: False 4.34
# l: False, r: True, success: False 4.35
# l: False, r: True, success: False 4.36
# l: False, r: True, success: False 4.37
# l: False, r: True, success: False 4.38
# l: False, r: True, success: False 4.39
# l: False, r: True, success: False 4.40
# l: False, r: True, success: False 4.41
# l: False, r: True, success: False 4.42
# l: False, r: True, success: False 4.43
# l: False, r: True, success: False 4.44
# l: False, r: True, success: False 4.45
# l: False, r: True, success: False 4.46
# l: False, r: True, success: False 4.47
# l: False, r: True, success: False 4.48
# l: False, r: True, success: False 4.49
# l: False, r: True, success: False 4.50
# l: False, r: True, success: False 4.51
# l: False, r: True, success: False 4.52
# l: False, r: True, success: False 4.53
# l: False, r: True, success: False 4.54
# l: False, r: True, success: False 4.55
# l: False, r: True, success: False 4.56
# l: False, r: True, success: False 4.57
# l: False, r: True, success: False 4.58
# l: False, r: True, success: False 4.59
# l: False, r: True, success: False 4.60
# l: False, r: True, success: False 4.61
# l: False, r: True, success: False 4.62
# l: False, r: True, success: False 4.63
# l: False, r: True, success: False 4.64
# l: False, r: True, success: False 4.65
# l: False, r: True, success: False 4.66
# l: False, r: True, success: False 4.67
# l: False, r: True, success: False 4.68
# l: False, r: True, success: False 4.69
# l: False, r: True, success: False 4.70
# l: False, r: True, success: False 4.71
# l: False, r: True, success: True 4.72

# %%
from typing import Callable, Literal

from tqdm import tqdm

from robot.sim import BimanualAction, BimanualObs

class GripperTracker:
  def __init__(self, arm: Literal['left', 'right']) -> None:
    if arm == 'left':
      self.kinematic_chain = LEFT_KINEMATIC_CHAIN
      self.get_joint_pos = lambda obs: obs.qpos.left_arm[:-2]
      self.get_gripper_error = lambda action, obs: obs.qpos.to_approximate_action().left_gripper - action.left_gripper
    else:
      self.kinematic_chain = RIGHT_KINEMATIC_CHAIN
      self.get_joint_pos = lambda obs: obs.qpos.right_arm[:-2]
      self.get_gripper_error = lambda action, obs: obs.qpos.to_approximate_action().right_gripper - action.right_gripper
    self.last_obs: BimanualObs | None = None
    self.last_stable_error = 0.0
    self.stability_duration = 0
  
  def update(self, action: BimanualAction, obs: BimanualObs):
    stability_threshold = 0.01
    self.last_obs = obs
    gripper_error = self.get_gripper_error(action, obs)
    if self.last_stable_error - stability_threshold < gripper_error < self.last_stable_error + stability_threshold:\
      self.stability_duration += 1
    else:
      self.last_stable_error = gripper_error
      self.stability_duration = 0

  def pos(self) -> np.ndarray:
    return kinematics.augmented_forward(self.kinematic_chain, self.get_joint_pos(self.last_obs), np.array([0.1, 0.0, 0.0]))[0]
  
  def is_stable(self) -> bool:
    return self.stability_duration > 10
  
  def is_gripping(self) -> bool:
    return self.last_stable_error > 0.2

def evaluate_rollout(create_sim: Callable[[], BimanualSim], policy: Callable[[BimanualObs], BimanualAction], max_steps_per_rollout: int) -> bool:
  left_gripper_tracker = GripperTracker('left')
  right_gripper_tracker = GripperTracker('right')

  with create_sim() as sim:
    obs = sim.get_obs()
    for _ in tqdm(range(max_steps_per_rollout)):
      action = policy(obs)
      obs = sim.step(action)

      left_gripper_tracker.update(action, obs)
      right_gripper_tracker.update(action, obs)

      block_pos = sim.data.xpos[mujoco.mj_name2id(sim.model, mujoco.mjtObj.mjOBJ_BODY, 'block')]
      right_gripper_distance = np.linalg.norm(block_pos - right_gripper_tracker.pos()).item()
      left_gripper_distance = np.linalg.norm(block_pos - left_gripper_tracker.pos()).item()
      if right_gripper_tracker.is_gripping() and right_gripper_distance < 0.05 and left_gripper_distance > 0.2:
        return True
  return False

sim = BimanualSim(merge_xml_files=[Path('block.xml')], on_mujoco_init=randomize_block_position)
policy = PrivilegedPolicy(sim.model, sim.data)
evaluate_rollout(lambda: sim, policy, max_steps_per_rollout=600)
# Out:
#  66%|██████▌   | 397/600 [01:44<00:53,  3.79it/s]
# True
